# %%
# typecasting
# input and out function in python
# float
# none
# complex
# string - intro

# %%
# typecasting - converting one datatype to another

int()
float()
str()
complex()
bool()

list()
tuple()
dict()
set()

# %%
a = 10
print(type(a))

# int to str
#1way
a = str(10)
print(type(a), a)


#2nd way
a = 10
print(type(str(a)), str(a))
# Out:
# <class 'int'>
# <class 'str'> 10
# <class 'str'> 10

# %%
a = 10.2
print(type(a), a)

print(int(a))
# Out:
# <class 'float'> 10.2
# 10

# %%
a = '100.40'

int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d4d37a3f5523> in <module>
#       1 a = '100.40'
#       2
# ----> 3 int(a)
#
# ValueError: invalid literal for int() with base 10: '100.40'

# %%
a = 0

bool(a)
# Out:
# False

# %%
a = 100
complex(a)
# Out:
# 100j

# %%
a = 100 + 7j
str(a)
# Out:
# '(100+7j)'

# %%
# Input and output function in python

# %%
Input - which takes input from the user
- input fucntion always return a string data type

# %%
a = 20
b = 20

print(a+b)
# Out:
# 40

# %%
a = input('enter the first number:')
b = input('enetr the second number')
print(type(a),a)
print(type(b) ,b)
print(a+b)
# Out:
# enter the first number:10
# enetr the second number10
# <class 'str'> 10
# <class 'str'> 10
# 1010

# %%
'10'+'10'
# Out:
# '1010'

# %%
a = float(input('enter the first number:'))
b = float(input('enetr the second number'))
print(type(a),a)
print(type(b) ,b)
print(a+b)
# Out:
# enter the first number:10
# enetr the second number20
# <class 'float'> 10.0
# <class 'float'> 20.0
# 30.0

# %%
# eval
sums = 200
a = eval(input('enter the first number:'))
b = eval(input('enetr the second number'))
print(type(a),a)
print(type(b) ,b)
print(a+b)
# Out:
# enter the first number:10
# enetr the second number20
# <class 'int'> 10
# <class 'int'> 20
# 30

# %%
# write a program to take first name and second name from user and print as a full name

a = (input('enter the first number:'))
b = (input('enetr the second number'))
print(a+" "+b)
# Out:
# enter the first number:afsan
# enetr the second numberkhan
# afsankhan

# %%
a = (input('enter the first number:'))
b = (input('enetr the second number'))
print(a,b)
# Out:
# enter the first number:afsan
# enetr the second numberkhan
# afsan khan

# %%
# my first name is afsan and second name is khan

a = input("Enter Your first Name : ")
b = input("Enter your Last Name : ")

print("My first Name is "+ a + " and second name "+ b)
# Out:
# Enter Your first Name : afsan
# Enter your Last Name : khan
# My first Name is afsan and second name khan

# %%
First_Name = eval(input("Enter first name : ") )
Last_Name = eval(input("Enter last name : ")) 
print("My First name is :", First_Name,"and my Last name is :",Last_Name)
# Out:
# Enter first name : 'afsan'
# Enter last name : 'khan'
# My First name is : afsan and my Last name is : khan

# %%
# format string

First_Name = eval(input("Enter first name : ") )
Last_Name = eval(input("Enter last name : ")) 
print(f"{First_Name} my first name is  and last name is {Last_Name}")
# Out:
# Enter first name : 'afsan'
# Enter last name : 'khan'
# my first name is afsan and last name is khan

# %%
First_Name = input("Enter first name : ")
Last_Name = input("Enter last name : ") 
print("{} my first name is  and last name is {}".format(First_Name, Last_Name))
# Out:
# Enter first name : 'afsan'
# Enter last name : 'khan'
# afsan my first name is  and last name is khan

# %%
output - to give output to the user

print(a)

# %%
a = 10
b = 20
c = 30

print(a, end="*")
print(b, end="*")
print(c, end="*")
# Out:
# 10*20*30
# 10 20 30

# %%
10*20*30*10 20 30

# %%
a = 10
b = 20
c = 30

print(a,b,c,sep='\n')
# Out:
# 10+20+30

# %%
a = 10
b = 20
c = 30
d = 40
e = 50

print(a,b,end='++')
print(a,e,sep='\n\n', end='$$')
print(a,b,c,sep='-->' , end='====')
print(d,e,sep='&&' , end='hey')
# Out:
# 10 20++10
#
# 50$$10-->20-->30====40&&50hey

# %%
# Out:
# afsan
#
# khan

# %%
10 20++10

50$$10-->20-->30\\\\40&&50hey

# %%
a = input()
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-038064e913d8> in <module>
# ----> 1 a = input()
#       2 print(a)
#
# /home/hulk/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /home/hulk/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
a = 10
print(a)

# %%
# Float data type

- any number wiht the decimal point eg - 99.0 , 100.99

# %%
a = 10.2
print(type(a) , a)
# Out:
# <class 'float'> 10.2

# %%
# Operation in floats
- arthmetic
- comaprison
- Equality
- logical
- identity
- assignment except bitwsise

# not possible

- bitwise op
- assignment except bitwise
- membership

Object Reuseablity is not applicable

# %%
# Complex data type

- any number that can be repesented in the form of a+bj where a is the real part and
b is the imaginary part

# %%
a = 10+7j
print(a)
# Out:
# (10+7j)

# %%
a = 10+7j
print(a.real)
print(a.imag)
# Out:
# 10.0
# 7.0

# %%
# Operation in complex
- arthmetic
- Equality
- logical
- identity
- assignment except bitwsise

# not possible

- comparison
- bitwise op
- assignment except bitwise
- membership
- floor
- modulo

Object Reuseablity is not applicable

# %%
a = 10+6j
# Out:
# (100+7j)

# %%
10+6j == 100
# Out:
# False

# %%
10+6j%2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-f49cdf87da40> in <module>
# ----> 1 10+6j%2
#
# TypeError: can't mod complex numbers.

# %%
# None data type

a = None

print(type(a))
# Out:
# <class 'NoneType'>

# %%
emp_name  employ_id   employ_sal

abc          141         
xyz          None        None

# %%
a = b = 1000

print(id(a))
print(id(b))
# Out:
# 140042108358352
# 140042108358352

# %%
stack

b ---> x109
a ---> x109

# %%
int = 10

# %%
int(20)
# Out:
# 20

# %%
# Boolean data type

- true also means 1
- false also means 0

# %%
int(True)
# Out:
# 1

# %%
# int - 0 is always false and rest is true

# float - 0.0 is always false and rest is true

# complex - 0+0j is always false and rest is true

# str - "" is always false and rest is true

# None - it is always false

empty list , tuple , dic , set -- false

# %%
# Operation in None

- Equality
- logical
- identity


# not possible
- assignment except bitwsise
- arthmetic
- comparison
- bitwise op
- assignment except bitwise
- membership
- floor
- modulo

Object Reuseablity is applicable
# Out:
# True

# %%
None + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3fd8740bf8ab> in <module>
# ----> 1 None + 1
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
None == None
# Out:
# True

# %%
print(None and 1)
# Out:
# None

# %%
print ("Hello world")
Print()
